# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import time
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup

import html5lib

# %%
url = 'https://www.seoul.go.kr/coronaV/coronaStatus.do'

header= {
    'referer':' https://www.seoul.go.kr/',
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
}

# %%
table = pd.read_html(url)

len(table)
# Out:
# 6

# %%
table[3]
# Out:
# Empty DataFrame
# Columns: [연번, 환자, 확진일, 거주지, 여행력, 접촉력, 퇴원현황]
# Index: []

# %%
'''
response = requests.post(url, headers=header)
data = json.loads(response.text)
data[0]
'''

# %%
response = requests.get(url).text

# %%
data = BeautifulSoup(response, 'html.parser')

# %%
data
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <title>서울시 코로나19</title>
# <meta content="서울시 코로나19 통합정보 사이트로 안전·방역(발생동향, 클린존, 선별진료소, 해외입국자 안내, 일일브리핑, 홍보물&amp;공적 공급마스크, 보도자료, 일일 소식지&amp;대응일지, 신고(응답소)), 생활정보(주요뉴스, 생활경제 지원, 온라인전시&amp;공연, 온라인도서관, 온라인체육관, 시민생활수기, 언론사 팩트체크, 심리지원), 시민 참여(잠시멈춤 캠페인, 온-서울캠페인, 시민제안)등의 정보를 제공하고 있습니다." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="서울시 코로나19 통합사이트" property="og:title"/>
# <meta content="서울시 코로나19 통합정보 사이트로 안전·방역(발생동향, 클린존, 선별진료소, 해외입국자 안내, 일일브리핑, 홍보물&amp;공적 공급마스크, 보도자료, 일일 소식지&amp;대응일지, 신고(응답소)), 생활정보(주요뉴스, 생활경제 지원, 온라인전시&amp;공연, 온라인도서관, 온라인체육관, 시민생활수기, 언론사 팩트체크, 심리지원), 시민 참여(잠시멈춤 캠페인, 온-서울캠페인, 시민제안)등의 정보를 제공하고 있습니다." property="og:description"/>
# <meta content="https://www.seoul.go.kr/coronaV/coronaStatus.do" property="og:url"/>
# <meta content="https://www.seoul.go.kr/res_newseoul/images/corona/sns_campaign0201.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="서울시 코로나19 통합사이트" name="twitter:title"/>
# <meta content="서울시 코로나19 통합정보 사이트로 안전·방역(발생동향, 클린존, 선별진료소, 해외입국자 안내, 일일브리핑, 홍보물&amp;공적 공급마스크, 보도자료, 일일 소식지&amp;대응일지, 신고(응답소)), 생활정보(주요뉴스, 생활경제 지원, 온라인전시&amp;공연, 온라인도서관, 온라인체육관, 시민생활수기, 언론사 팩트체크, 심리지원), 시민 참여(잠시멈춤 캠페인, 온-서울캠페인, 시민제안)등의 정보를 제공하고 있습니다." name="twitter:description"/>
# <meta content="https://www.seoul.go.kr/coronaV/coronaStatus.do" name="twitter:domain"/>
# <meta content="https://www.seoul.go.kr/res_newseoul/images/corona/sns_campaign0201.jpg" name="twitter:image"/>
# <link href="/res_newseoul/css/reset.css?20191024110103" rel="stylesheet"/>
# <link href="/res_newseoul/css/corona_new.css?20210126" rel="stylesheet"/>
# <link href="https://www.seoul.go.kr/coronaV/coronaStatus.do" rel="canonical">
# <link href="/res_newseoul/css/jquery-ui.min.css" rel="stylesheet"/>
# <script src="/res_newseoul/js/jquery-1.12.2.min.js"></script>
# <script src="/res_newseoul/js/jquery-ui.min.js"></script>
# <script src="/res_newseoul/js/comapp.js?20200211164103"></script>
# <script src="/res_newseoul/js/Chart.min.js"></script>
# <script src="/res_newseoul/js/utils.js"></script>
# <script src="/res_newseoul/js/clipboard.min.js"></script>
# <script src="https://101.livere.co.kr/js/livere8_lib.js?ver=4.3.1"></script>
# <script>
# 		function goTwitter(title,link){
# 			var w = (screen.width-450)/2;
# 			var h = (screen.height-450)/2;
# 			var href = "http://twitter.com/share?text=" + encodeURIComponent(title) + "&url=" + encodeURIComponent(link);
# 			var a = window.open(href, 'twitter', 'width=450,height=450,left='+w+',top='+h+',scrollbars=0');
# 			if(a) { a.focus(); }
# 		}
# 		function goFaceBook(msg,url){
# 			var href ="http://www.facebook.com/sharer.php?u="+encodeURIComponent(url)+"&t="+encodeURIComponent(msg);
# 			var a = window.open(href,'facebook','');
# 			if(a){ a.focus();}
# 		}
# 	</script>
# </link></meta></head>
# <body>
# <!-- serverTestContent -->
# <!-- ######################################################################## -->
# <!--
# 	menu name: serverTestContent
# -->
# <!-- ######################################################################## -->
# <div id="divTestOnOff" style="position: relative;width:100%;text-align:center;background: orange;display:none;">
# <section style="margin: 0 auto;padding:10px 0;">
# <h2 id="h2TestName" style="font-size: 20px;color: #f4f6f7;font-weight: 700;"></h2>
# </section>
# </div>
# <script>
# 	var local_hostname = window.location.hostname;
# 	var divTestOnOff = $("#divTestOnOff");
# 	if(divTestOnOff){
# 		if(local_hostname == "testwww.seoul.go.kr" || local_hostname == "127.0.0.1" || local_hostname == "localhost"){
# 			divTestOnOff.show();
# 			$("#h2TestName").text("로컬(개발서버)");
# 			if(local_hostname == "testwww.seoul.go.kr"){
# 				$("#h2TestName").text("테스트서버");
# 			}
#
# 		}
# 	}
#
# </script>
# <!-- serverTestContent -->
# <div class="sub" id="wrap">
# <div id="skip"><a href="#container">본문 내용 바로가기</a></div>
# <header id="header">
# <div class="layout-inner">
# <div class="logo-wrap">
# <p class="seoul-logo"><a class="logo-seoul" href="//www.seoul.go.kr" target="_blank"><img alt="I SEOUL U 너와 나의 서울" src="/res_newseoul/images/corona/logo_iseoullu.png"/></a></p>
# </div>
# <div class="menu-wrap">
# <div class="logo"><h1><a href="//www.seoul.go.kr/coronaV/coronaStatus.do"><img alt="코로나19 (COVID-19)" class="logo-pc" src="/res_newseoul/images/corona/logo_covid19_pc.png"/><img alt="코로나19 (COVID-19)" class="logo-mobile" src="/res_newseoul/images/corona/logo_covid19_mo.png"/></a></h1></div>
# <button class="btn-menu-open" type="button"><span>메뉴접기</span></button>
# <div class="bg-visual"></div>
# <ul id="menu">
# <li class="menu1 selected active"><a href="http://www.seoul.go.kr/coronaV/coronaStatus.do?menu_code=01"><span>안전·방역</span></a>
# <ul class="sub-menu">
# <li class="on"><a href="/coronaV/coronaStatus.do?menu_code=01">발생동향</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=19">생활 속 거리두기 기본지침</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=23">마스크 착용 준수 안내</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=03">선별진료소/임시선별검사소</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=17">해외입국자 안내</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=04">서울시 브리핑</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=05">홍보물</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=06">보도자료</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=07">일일 소식지&amp;대응일지</a></li>
# <li><a href="http://mediahub-corona19.seoul.go.kr/corona19/#fact" target="_blank">팩트체크</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=24">코로나19 Q&amp;A</a></li>
# </ul>
# </li>
# <li class="menu2 selected active"><a href="/coronaV/coronaStatus.do?menu_code=18" target="_blank"><span>생활정보</span></a>
# <ul class="sub-menu">
# <li><a href="/coronaV/coronaStatus.do?menu_code=18" target="_blank">코로나19 지원금 확인</a></li>
# <li><a href="http://mediahub-corona19.seoul.go.kr/corona19/#news" target="_blank">코로나19 주요뉴스</a></li>
# <li><a href="http://mediahub-corona19.seoul.go.kr/corona19/#support" target="_blank">생활경제 지원 정책</a></li>
# <li><a href="http://covid19seoulmind.org/" target="_blank">심리지원</a></li>
# </ul>
# </li>
# <li class="menu3 selected active"><a href="/coronaV/coronaStatus.do?menu_code=21"><span>시민참여</span></a>
# <ul class="sub-menu">
# <li><a href="https://mediahub-corona19.seoul.go.kr/mask_campaign/" target="_blank">마스크 꼭! 캠페인</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=21">코로나19 응원공모 수상작</a></li>
# <li><a href="https://mediahub-corona19.seoul.go.kr/corona19stop/" target="_blank">잠시멈춤 캠페인</a></li>
# <li><a href="https://democracy.seoul.go.kr/front/crm/bbs/102/list.do" target="_blank">온-서울 캠페인</a>
# <ul class="sub-menu-3depth">
# <li><a href="/coronaV/coronaStatus.do?menu_code=15">따뜻한 방역</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=15">따뜻한 연결</a></li>
# <li><a href="/coronaV/coronaStatus.do?menu_code=15">따뜻한 경제</a></li>
# </ul>
# </li>
# <li><a href="http://democracy.seoul.go.kr/front/allSuggest/list.do" target="_blank">시민제안</a></li>
# </ul>
# </li>
# </ul>
# <div class="sns-wrap">
# <a class="ico-sns" href="https://www.facebook.com/seoul.kr" target="_blank"><img alt="페이스북" src="/res_newseoul/images/corona/img_facebook.png"/></a>
# <a class="ico-sns" href="https://www.youtube.com/seoullive" target="_blank"><img alt="유튜브" src="/res_newseoul/images/corona/img_youtube.png"/></a>
# <a class="ico-sns" href="http://story.kakao.com/ch/seoul" target="_blank"><img alt="카카오채널" src="/res_newseoul/images/corona/img_kakao.png"/></a>
# </div>
# </div>
# </div>
# <!--// .inner -->
# </header>
# <!--// .header -->
# <script>
#
# 		jQuery(document).ready(function($){
# 			 $('.counter').counterUp({
# 				delay: 10,
# 				time: 1000
# 			});
#
# 			//$("#statueId").show();
# 			//$("#rsstableId").show();
# 		});
#
# </script>
# <div id="container">
# <div class="breadcrumb-wrap">
# <div class="breadcrumb">
# <a class="home" href="//www.seoul.go.kr/coronaV/coronaStatus.do">Home</a>  &gt; 안전·방역  &gt;  발생동향
# 			</div>
# </div>
# <div class="layout-inner layout-sub">
# <div class="inner inner7">
# <div class="share">
# <button class="icon-share icon-share-facebook" onclick="javascript:goFaceBook('코로나19 발생동향','http://www.seoul.go.kr/coronaV/coronaStatus.do?menu_code=01')" type="button">페이스북</button>
# <button class="icon-share icon-share-twitter" onclick="javascript:goTwitter('코로나19 발생동향','http://www.seoul.go.kr/coronaV/coronaStatus.do?menu_code=01')" type="button">트위터</button>
# <input class="sr-only" id="link1-1" tabindex="-1" title="현재페이지 링크 주소" type="text" value="http://www.seoul.go.kr/coronaV/coronaStatus.do?menu_code=01"/>
# <button class="icon-share icon-share-share" data-clipboard-action="copy" data-clipboard-target="#link1-1">링크복사</button>
# </div>
# <h3 class="h3-status"><span>발생동향</span></h3>
# <div class="status">
# <div class="status-seoul">
# <h4>서울시 <span>('21.02.04.00시 기준)</span></h4>
# <div class="cell-group first-cell">
# <div class="cell cell1">
# <div class="num num10">
# <div class="num-wrap-new">
# <p class="counter">172</p>
# <p class="txt">추가 확진자</p>
# </div>
# </div>
# <div class="num num1">
# <p class="counter">24,755</p>
# <p class="txt">확진자</p>
# </div>
# </div>
# <!-- 격리중 추가 2020-07-23 -->
# <div class="cell cell7">
# <div class="num num8">
# <p class="counter">3,655</p>
# <p class="txt">치료중</p>
# </div>
# </div>
# <!-- 퇴원 추가 -->
# <div class="cell cell5">
# <div class="num num11">
# <div class="num-wrap-new">
# <p class="counter">78</p>
# <p class="txt">추가 퇴원</p>
# </div>
# </div>
# <div class="num num8">
# <p class="counter">20,771</p>
# <p class="txt">퇴원</p>
# </div>
# </div>
# <!-- 사망 추가 -->
# <div class="cell cell6">
# <div class="num num9">
# <p class="counter">329</p>
# <p class="txt">사망</p>
# </div>
# </div>
# </div>
# </div>
# <div class="status-korea">
# <h4>대한민국 <span>('21.02.04.00시 기준)</span></h4>
# <div class="status-korea-cell">
# <div class="cell cell4">
# <div class="num knum5">
# <div class="num-wrap-new">
# <p class="counter">451</p>
# <p class="txt">추가 확진자</p>
# </div>
# </div>
# <div class="num knum1">
# <p class="counter">79,762</p>
# <p class="txt">확진자</p>
# </div>
# <div class="num knum4">
# <!-- 치료중 : 확진자수 – 퇴원 - 사망 -->
# <p class="counter">8,610</p>
# <p class="txt">치료중</p>
# </div>
# <div class="num knum3">
# <p class="counter">69,704</p>
# <p class="txt">퇴원</p>
# </div>
# <div class="num knum2">
# <p class="counter">1,448</p>
# <p class="txt">사망</p>
# </div>
# </div>
# </div>
# <!--// .status-korea-cell -->
# </div>
# <div class="kcdc">
# <a href="http://ncov.mohw.go.kr" target="_blank"><img alt="질병관리청 kdca" src="/res_newseoul/images/corona/logo_kdca.png"/></a>
# </div>
# </div>
# <!--// .status -->
# <!-- 배너존 (스미싱 513373) -->
# <div class="display-none dnone" style="margin: 0 0 10px;"><a href="https://news.seoul.go.kr/welfare/archives/525381" rel="noopener noreferrer" target="_blank"><img alt="코로나19 자치구 임시선별검사소 운영 현황. 유,무증상자 누구나 익명으로 무료 검사 받으실 수 있습니다." class="pc alignnone size-full wp-image-514289" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/5fd7169677bef7.79065496.jpg" width="1000"/><img alt="코로나19 자치구 임시선별검사소 운영 현황. 유,무증상자 누구나 익명으로 무료 검사 받으실 수 있습니다." class="mobile alignnone size-full wp-image-514290" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/5fd716ac6c2017.42563213.jpg" width="640"/></a></div><div class="display-none dnone" style="margin: 0 0 10px;"><a href="https://news.seoul.go.kr/welfare/archives/526865" rel="noopener noreferrer" target="_blank"><img alt="코로나 19 사회적 거리두기 2.5단계 실시 마스크착용 의무화" class="pc alignnone size-full wp-image-514289" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/6001429dcb1a60.60028605.jpg" width="1000"/><img alt="코로나 19 사회적 거리두기 2.5단계 실시 마스크착용 의무화" class="mobile alignnone size-full wp-image-514290" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/600142b9e53b79.20151627.jpg" width="640"/></a></div><div class="display-none dnone" style="margin: 0 0 10px;"><a href="https://news.seoul.go.kr/safe/archives/505588" rel="noopener noreferrer" target="_blank"><img alt="QR코드 전자출입명부(KI-Pass) 안내 소책자(시설관리자+이용자용/지자체용)" class="pc alignnone size-full wp-image-514289" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/5f4c808d1cbf47.53330726.jpg" width="1000"/><img alt="QR코드 전자출입명부(KI-Pass) 안내 소책자(시설관리자+이용자용/지자체용)" class="mobile alignnone size-full wp-image-514290" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/5f4c80b93e6934.63871417.jpg" width="640"/></a></div><div class="display-none dnone" style="margin: 0 0 10px;"><a href="https://eungdapso.seoul.go.kr/Req/Req02/Req02_not2.jsp" rel="noopener noreferrer" target="_blank"><img alt="코로나19 신고센터 집단감염 위험 준수사항 위반 신고" class="pc alignnone size-full wp-image-514289" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/5f3b3c601ec900.32031232.png" width="1000"/><img alt="코로나19 신고센터 집단감염 위험 준수사항 위반 신고" class="mobile alignnone size-full wp-image-514290" height="200" src="//news.seoul.go.kr/welfare/files/2020/02/5f3b3cf01d9827.77919248.png" width="640"/></a></div><div class="display-block"><p><img alt="스미싱" class="alignnone size-full wp-image-513468 aligncenter" src="//www.seoul.go.kr/res_newseoul/images/corona/welfare-smishing.jpg"/></p><p> </p><p> </p><h5 style="margin: 0px; padding: 10px 0px 0px; text-align: center; color: #007297; text-transform: none; line-height: 25.6px; text-indent: 0px; letter-spacing: normal; clear: both; font-family: 'Nanum Gothic'; font-size: 1em; font-style: normal; font-weight: bold; word-spacing: 0px; white-space: normal; -ms-word-break: keep-all; orphans: 2; widows: 2; overflow-wrap: break-word; font-variant-ligatures: normal; font-variant-caps: normal; -webkit-text-stroke-width: 0px; text-decoration-style: initial; text-decoration-color: initial;"><span><strong><a href="https://www.police.go.kr/www/security/cyber.jsp" rel="noopener noreferrer" style="color: #800000; text-decoration: underline; -ms-word-break: keep-all; overflow-wrap: break-word;" target="_blank" title="사이버안전지킴이 신고하기&gt;&gt;">사이버범죄 신고하기</a></strong></span><span><strong> &gt;&gt;</strong></span></h5></div>
# <!--// 배너 -->
# <!-- tab -->
# <div class="move-tab">
# <ul>
# <li><button class="on" data-url="#move-cont1" type="button">확진자 <span>현황</span></button></li>
# <li><button class="btn-tab2" data-url="#move-cont2" type="button">확진자 <span>이동경로</span></button></li>
# <li><button class="btn-tab3" data-url="#move-cont3" type="button">확진자 <span>추이</span></button></li>
# </ul>
# </div>
# <div class="move-cont" id="move-cont1" style="display: block">
# <!-- 확진자 현황(자치구별) : START -->
# <div class="status-confirm map-status display-none">
# <h4>확진자 현황(자치구별)</h4>
# <p class="txt-status">('21.02.04.00시 기준)</p>
# <div class="seoul-map-wrap">
# <div class="seoul-map seoul-map-all">
# <img alt="서울시 지도" src="/res_newseoul/images/corona/img_basic_map1.png"/>
# <span class="district district1 on"><em class="sr-only">종로구</em><span class="num">519</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district1.png"/></span></span>
# <span class="district district2 on"><em class="sr-only">강서구</em><span class="num">1569</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district2.png"/></span></span>
# <span class="district district3 on"><em class="sr-only">성북구</em><span class="num">1045</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district3.png"/></span></span>
# <span class="district district4 on"><em class="sr-only">서대문구</em><span class="num">672</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district4.png"/></span></span>
# <span class="district district5 on"><em class="sr-only">성동구</em><span class="num">601</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district5.png"/></span></span>
# <span class="district district6 on"><em class="sr-only">서초구</em><span class="num">981</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district6.png"/></span></span>
# <span class="district district7 on"><em class="sr-only">중랑구</em><span class="num">1036</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district7.png"/></span></span>
# <span class="district district8 on"><em class="sr-only">강동구</em><span class="num">766</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district8.png"/></span></span>
# <span class="district district9 on"><em class="sr-only">구로구</em><span class="num">799</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district9.png"/></span></span>
# <span class="district district10 on"><em class="sr-only">송파구</em><span class="num">1389</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district10.png"/></span></span>
# <span class="district district11 on"><em class="sr-only">마포구</em><span class="num">864</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district11.png"/></span></span>
# <span class="district district12 on"><em class="sr-only">은평구</em><span class="num">986</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district12.png"/></span></span>
# <span class="district district13 on"><em class="sr-only">관악구</em><span class="num">1207</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district13.png"/></span></span>
# <span class="district district14 on"><em class="sr-only">금천구</em><span class="num">402</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district14.png"/></span></span>
# <span class="district district15 on"><em class="sr-only">중구</em><span class="num">381</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district15.png"/></span></span>
# <span class="district district16 on"><em class="sr-only">용산구</em><span class="num">543</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district16.png"/></span></span>
# <span class="district district17 on"><em class="sr-only">광진구</em><span class="num">601</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district17.png"/></span></span>
# <span class="district district18 on"><em class="sr-only">동대문구</em><span class="num">915</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district18.png"/></span></span>
# <span class="district district19 on"><em class="sr-only">강북구</em><span class="num">649</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district19.png"/></span></span>
# <span class="district district20 on"><em class="sr-only">도봉구</em><span class="num">757</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district20.png"/></span></span>
# <span class="district district21 on"><em class="sr-only">노원구</em><span class="num">1050</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district21.png"/></span></span>
# <span class="district district22 on"><em class="sr-only">양천구</em><span class="num">909</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district22.png"/></span></span>
# <span class="district district23 on"><em class="sr-only">영등포구</em><span class="num">900</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district23.png"/></span></span>
# <span class="district district24 on"><em class="sr-only">동작구</em><span class="num">1025</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district24.png"/></span></span>
# <span class="district district25 on"><em class="sr-only">강남구</em><span class="num">1179</span><span class="img-on"><img alt="" src="/res_newseoul/images/corona/img_on_district25.png"/></span></span>
# <a class="dist dist1" href="http://www.jongno.go.kr" target="_blank">종로구</a>
# <a class="dist dist2" href="http://www.junggu.seoul.kr" target="_blank">중구</a>
# <a class="dist dist3" href="http://www.yongsan.go.kr" target="_blank">용산구</a>
# <a class="dist dist4" href="http://www.sd.go.kr/sd/intro.do" target="_blank">성동구</a>
# <a class="dist dist5" href="http://www.gwangjin.go.kr" target="_blank">광진구</a>
# <a class="dist dist6" href="http://www.ddm.go.kr" target="_blank">동대문구</a>
# <a class="dist dist7" href="https://www.jungnang.go.kr/intro.jsp" target="_blank">중랑구</a>
# <a class="dist dist8" href="http://www.sb.go.kr" target="_blank">성북구</a>
# <a class="dist dist9" href="http://www.gangbuk.seoul.kr" target="_blank">강북구</a>
# <a class="dist dist10" href="http://www.dobong.go.kr" target="_blank">도봉구</a>
# <a class="dist dist11" href="https://www.nowon.kr/corona19/index.do" target="_blank">노원구</a>
# <a class="dist dist12" href="https://www.ep.go.kr/CmsWeb/viewPage.req?idx=PG0000004918" target="_blank">은평구</a>
# <a class="dist dist13" href="http://www.sdm.go.kr/index.do" target="_blank">서대문구</a>
# <a class="dist dist14" href="http://www.mapo.go.kr" target="_blank">마포구</a>
# <a class="dist dist15" href="http://www.yangcheon.go.kr/site/yangcheon/coronaStatusList.do" target="_blank">양천구</a>
# <a class="dist dist16" href="http://www.gangseo.seoul.kr/new_portal/living/safe/page06_07.jsp" target="_blank">강서구</a>
# <a class="dist dist17" href="https://www.guro.go.kr/corona2.jsp" target="_blank">구로구</a>
# <a class="dist dist18" href="http://www.geumcheon.go.kr" target="_blank">금천구</a>
# <a class="dist dist19" href="http://www.ydp.go.kr" target="_blank">영등포구</a>
# <a class="dist dist20" href="http://www.dongjak.go.kr" target="_blank">동작구</a>
# <a class="dist dist21" href="https://blog.naver.com/gwanak_gu" target="_blank">관악구</a>
# <a class="dist dist22" href="https://www.seocho.go.kr/html/notice/main.jsp" target="_blank">서초구</a>
# <a class="dist dist23" href="http://www.gangnam.go.kr" target="_blank">강남구</a>
# <a class="dist dist24" href="http://www.songpa.go.kr" target="_blank">송파구</a>
# <a class="dist dist25" href="http://www.gangdong.go.kr" target="_blank">강동구</a>
# </div>
# <div class="seoul-map seoul-map-other on">
# <img alt="기타 " src="/res_newseoul/images/corona/img_basic_other.png"/>
# <span class="district district26"><em class="sr-only">기타</em><span class="num">3010</span></span>
# </div>
# <div class="seoul-map seoul-map-check">
# <img alt="확인중" src="/res_newseoul/images/corona/img_basic_check.png"/>
# <span class="district district26"><em class="sr-only">확인중</em><span class="num"></span></span>
# </div>
# </div>
# </div>
# <!--// 확진자 현황(자치구별) : END -->
# <!-- 확진자 현황 : START -->
# <div class="status-confirm" style="padding: 0 0 20px;">
# <table class="tstyle-status pc pc-table" style="width: 100%;margin-bottom: 40px">
# <caption>서울시 구별 확진자 현황</caption>
# <tbody>
# <tr>
# <th scope="col">종로구</th>
# <th scope="col">중구</th>
# <th scope="col">용산구</th>
# <th scope="col">성동구</th>
# <th scope="col">광진구</th>
# <th scope="col">동대문구</th>
# <th scope="col">중랑구</th>
# <th scope="col">성북구</th>
# <th scope="col">강북구</th>
# <th scope="col">도봉구</th>
# <th scope="col">노원구</th>
# <th scope="col">은평구</th>
# <th scope="col">서대문구</th>
# </tr>
# <tr>
# <td>519</td>
# <td>381</td>
# <td>543</td>
# <td>601</td>
# <td>601</td>
# <td>915</td>
# <td>1036</td>
# <td>1045</td>
# <td>649</td>
# <td>757</td>
# <td>1050</td>
# <td>986</td>
# <td>672</td>
# </tr>
# <tr>
# <td class="today">+2</td>
# <td class="today">+5</td>
# <td class="today">+6</td>
# <td class="today">+5</td>
# <td class="today">+7</td>
# <td class="today">+6</td>
# <td class="today">+19</td>
# <td class="today">+9</td>
# <td class="today">+9</td>
# <td class="today">+6</td>
# <td class="today">+8</td>
# <td class="today">+2</td>
# <td class="today">+4</td>
# </tr>
# <tr>
# <th scope="col">마포구</th>
# <th scope="col">양천구</th>
# <th scope="col">강서구</th>
# <th scope="col">구로구</th>
# <th scope="col">금천구</th>
# <th scope="col">영등포구</th>
# <th scope="col">동작구</th>
# <th scope="col">관악구</th>
# <th scope="col">서초구</th>
# <th scope="col">강남구</th>
# <th scope="col">송파구</th>
# <th scope="col">강동구</th>
# <th scope="col">기타</th>
# </tr>
# <tr>
# <td>864</td>
# <td>909</td>
# <td>1569</td>
# <td>799</td>
# <td>402</td>
# <td>900</td>
# <td>1025</td>
# <td>1207</td>
# <td>981</td>
# <td>1179</td>
# <td>1389</td>
# <td>766</td>
# <td>3010</td>
# </tr>
# <tr>
# <td class="today">+5</td>
# <td class="today">+9</td>
# <td class="today">+4</td>
# <td class="today">+7</td>
# <td class="today">+3</td>
# <td class="today">+5</td>
# <td class="today">+4</td>
# <td class="today">+4</td>
# <td class="today">+6</td>
# <td class="today">+6</td>
# <td class="today">+12</td>
# <td class="today">+6</td>
# <td class="today">+13</td>
# </tr>
# </tbody>
# </table>
# <table class="tstyle-status mobile mobile-table" style="width: 100%;margin-bottom: 40px">
# <caption>서울시 구별 확진자 현황</caption>
# <tbody>
# <tr>
# <th scope="col">종로구</th>
# <th scope="col">중구</th>
# <th scope="col">용산구</th>
# <th scope="col">성동구</th>
# <th scope="col">광진구</th>
# <th scope="col">동대문구</th>
# </tr>
# <tr>
# <td>519</td>
# <td>381</td>
# <td>543</td>
# <td>601</td>
# <td>601</td>
# <td>915</td>
# </tr>
# <tr>
# <td class="today">+2</td>
# <td class="today">+5</td>
# <td class="today">+6</td>
# <td class="today">+5</td>
# <td class="today">+7</td>
# <td class="today">+6</td>
# </tr>
# <tr>
# <th scope="col">중랑구</th>
# <th scope="col">성북구</th>
# <th scope="col">강북구</th>
# <th scope="col">도봉구</th>
# <th scope="col">노원구</th>
# <th scope="col">은평구</th>
# </tr>
# <tr>
# <td>1036</td>
# <td>1045</td>
# <td>649</td>
# <td>757</td>
# <td>1050</td>
# <td>986</td>
# </tr>
# <tr>
# <td class="today">+19</td>
# <td class="today">+9</td>
# <td class="today">+9</td>
# <td class="today">+6</td>
# <td class="today">+8</td>
# <td class="today">+2</td>
# </tr>
# <tr>
# <th scope="col">서대문구</th>
# <th scope="col">마포구</th>
# <th scope="col">양천구</th>
# <th scope="col">강서구</th>
# <th scope="col">구로구</th>
# <th scope="col">금천구</th>
# </tr>
# <tr>
# <td>672</td>
# <td>864</td>
# <td>909</td>
# <td>1569</td>
# <td>799</td>
# <td>402</td>
# </tr>
# <tr>
# <td class="today">+4</td>
# <td class="today">+5</td>
# <td class="today">+9</td>
# <td class="today">+4</td>
# <td class="today">+7</td>
# <td class="today">+3</td>
# </tr>
# <tr>
# <th scope="col">영등포구</th>
# <th scope="col">동작구</th>
# <th scope="col">관악구</th>
# <th scope="col">서초구</th>
# <th scope="col">강남구</th>
# <th scope="col">송파구</th>
# </tr>
# <tr>
# <td>900</td>
# <td>1025</td>
# <td>1207</td>
# <td>981</td>
# <td>1179</td>
# <td>1389</td>
# </tr>
# <tr>
# <td class="today">+5</td>
# <td class="today">+4</td>
# <td class="today">+4</td>
# <td class="today">+6</td>
# <td class="today">+6</td>
# <td class="today">+12</td>
# </tr>
# <tr>
# <th scope="col">강동구</th>
# <th scope="col">기타</th>
# <th colspan="4"></th>
# </tr>
# <tr>
# <td>766</td>
# <td>3010</td>
# <td colspan="4"></td>
# </tr>
# <tr>
# <td class="today">+6</td>
# <td class="today">+13</td>
# <td colspan="4"></td>
# </tr>
# </tbody>
# </table>
# <h4>서울 확진자 현황</h4>
# <h5 class="update-date" style="text-align: right;"><strong>('21.02.04.00시 기준)</strong></h5>
# <!-- 확진자 현황표 -->
# <div class="display-none new">
# <table class="tstyle05 tstyle-status">
# <caption>서울 확진자 현황 - 감염경로에 해당하는 확진자 정보</caption>
# <thead>
# <tr class="odd">
# <th scope="col">소계</th>
# <th scope="col">
# <p>
# <b>해외유입</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>성동구 소재 병원 관련(’21.1월)</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>광진구 소재 음식점 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>중구 소재 복지시설 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>관악구 소재 의료기관 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>동대문구 소재 고시텔 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>강동구 소재 한방병원 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>성북구 소재 사우나 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>영등포구 소재 의료기관2 관련</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>기타 집단 감염</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>기타 확진자 접촉</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>타시도 확진자 접촉</b>
# </p>
# </th>
# <th scope="col">
# <p>
# <b>감염경로 조사중</b>
# </p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th data-tit="소계" scope="row"><strong>24755</strong></th>
# <td data-tit="해외유입"><strong>815</strong></td>
# <td data-tit="성동구 소재 병원 관련(’21.1월)"><strong>65</strong></td>
# <td data-tit="광진구 소재 음식점 관련"><strong>45</strong></td>
# <td data-tit="중구 소재 복지시설 관련"><strong>74</strong></td>
# <td data-tit="관악구 소재 의료기관 관련"><strong>17</strong></td>
# <td data-tit="동대문구 소재 고시텔 관련"><strong>15</strong></td>
# <td data-tit="강동구 소재 한방병원 관련"><strong>20</strong></td>
# <td data-tit="성북구 소재 사우나 관련"><strong>17</strong></td>
# <td data-tit="영등포구 소재 의료기관2 관련"><strong>15</strong></td>
# <td data-tit="기타 집단 감염"><strong>9097</strong></td>
# <td data-tit="기타 확진자 접촉"><strong>7751</strong></td>
# <td data-tit="타시도 확진자 접촉"><strong>1107</strong></td>
# <td data-tit="감염경로 조사중"><strong>5717</strong></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="tab-cont-wrap">
# <div class="new-tab">
# <ul>
# <li><button class="on" data-url="#new-cont1" type="button">확진자 현황 <span>(10001번~현재)</span></button></li>
# <li><button data-url="#new-cont2" type="button">확진자 현황 <span>(1번~10000번)</span></button></li>
# </ul>
# </div>
# <div class="new-cont" id="new-cont1" style="display: block">
# <div id="statueId">
# <link href="//www.seoul.go.kr/res_newseoul/css/jquery.dataTables.css?ver=20201218" rel="stylesheet" type="text/css"/>
# <script src="//www.seoul.go.kr/res_newseoul/js/jquery.dataTables.js"></script>
# <script>
#
# jQuery(document).ready(function() {
#
# 	jQuery('.btn-paging').on('click', function(){
# 		var ids = jQuery(this).attr('data-tit');
# 		jQuery(this).closest('.cont-page-wrap').find('.btn-paging').removeClass('on');
# 		jQuery(this).addClass('on');
# 		jQuery(this).closest('.cont-page-wrap').find('.cont-page').css('display', 'none');
# 		jQuery('#'+ids).css('display', 'block');
# 		jQuery('html, body').animate({scrollTop:jQuery('#'+ids).offset().top}, 'fast');
# 	});
#
# });
#
# </script>
# <div class="cont-page-wrap" id="status_box">
# <a name="status_page_top"></a>
# <div class="search-box">
# <label for="status_searchArea">자치구 검색 :</label>
# <select id="status_searchArea">
# <option value="">자치구 전체</option>
# <option value="강남구">강남구</option>
# <option value="강동구">강동구</option>
# <option value="강북구">강북구</option>
# <option value="강서구">강서구</option>
# <option value="관악구">관악구</option>
# <option value="광진구">광진구</option>
# <option value="구로구">구로구</option>
# <option value="금천구">금천구</option>
# <option value="노원구">노원구</option>
# <option value="도봉구">도봉구</option>
# <option value="동대문구">동대문구</option>
# <option value="동작구">동작구</option>
# <option value="마포구">마포구</option>
# <option value="서대문구">서대문구</option>
# <option value="서초구">서초구</option>
# <option value="성동구">성동구</option>
# <option value="성북구">성북구</option>
# <option value="송파구">송파구</option>
# <option value="양천구">양천구</option>
# <option value="영등포구">영등포구</option>
# <option value="용산구">용산구</option>
# <option value="은평구">은평구</option>
# <option value="종로구">종로구</option>
# <option value="중구">중구</option>
# <option value="중랑구">중랑구</option>
# <option value="기타">기타</option>
# </select>
# <select id="status_pageLength" title="목록갯수 선택">
# <option value="10">10</option>
# <option value="25">25</option>
# <option value="50">50</option>
# <option selected="selected" value="100">100</option>
# </select>
# <input id="status_searchQuery" name="query" type="text" value=""/>
# <button class="btn-route-search" id="status_searchButton" style="display: inline-block;padding: 0 20px;height:2rem;line-height: 2rem;background: #ebebeb;border: 1px solid #ddd;" type="button">검색</button>
# <button class="btn-route-search" id="status_init_searchButton" style="display: none;padding: 0 20px;height:2rem;line-height: 2rem;background: #ebebeb;border: 1px solid #ddd;" type="button">초기화</button>
# </div>
# <table class="tstyle05 tstyleP status_datatable datatable-multi-row">
# <caption>서울 확진자 현황 - 연번, 환자, 확진일 등의 정보</caption>
# <colgroup>
# <col style="width: 10%;"/>
# <col style="width: 10%;"/>
# <col style="width: 10%;"/>
# <col style="width: 10%;"/>
# <col style="width: 20%;"/>
# <col style="width: 30%;"/>
# <col style="width: 10%;"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">연번</th>
# <th scope="col">환자</th>
# <th scope="col">확진일</th>
# <th scope="col">거주지</th>
# <th scope="col">여행력</th>
# <th scope="col">접촉력</th>
# <th scope="col">퇴원현황</th>
# </tr>
# </thead>
# </table>
# </div>
# <script>
#
# 	var status_etc_query = "기타|타시도";
# 	var status_ajax_url = "https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php";
# 	var status_settime = null;
# 	var status_is_first = true;
# 	var status_pre_is_first = true;
#
# 	var status_column_arr = ["","환자 번호","확진일","거주지","여행력","접촉력","퇴원현황"];
#
# 	var status_datatable = jQuery('.status_datatable').DataTable({
# 		columnDefs: [
# 			{type: 'natural', targets: 0}
# 		],
# 		"order" : [[0, "desc" ]],
# 		"pageLength" : 100,
# 		"search": {regex: true},
# 		"processing": true,
#         "serverSide": true,
#         "ajax": status_ajax_url,
# 		"fnDrawCallback": function() {
#
# 			//한번만 실행
# 			if(status_is_first){
# 				jQuery('.dataTables_processing').html('<img src="https://www.seoul.go.kr/res_newseoul/images/corona/ajax-loader.gif" alt="loading">');
# 			}
#
# 			var api = this.api();
# 			var page_info = api.page.info();
# 			var page_number = page_info.page +1;
#
# 			jQuery('#status_box').find(".paging_simple_numbers").append("<span class='page_move'><input id='go_number' type='text' class='page_number' value='"+page_number+"' /><input type='button' class='btn_page_number' onclick='go_to_page();' value='이동'/></span>");
#
# 			var rowCount = api.rows({search:'applied'}).count();
#
# 		    $table = jQuery(this);
#
# 		    $table.css("width","100%");
#
# 			if ($table.closest(".datatable-multi-row").length) {
#
# 				$table.find("tbody>tr").each(function(index) {
# 					var $tr = jQuery(this);
#
# 					//$tr.find("p.corona19_no").html(rowCount - (api.page.info().page * api.page.len()) - index);
#
# 					var extra_row = $tr.find(".extra-row-content").html();
#
# 					if (!$tr.next().hasClass('dt-added')) {
# 						$tr.after(extra_row);
#
# 						if($tr.find("td").eq(0)){
# 							var first = $tr.find("td").first();
# 							$(first).contents().unwrap().wrap("<th scope='row' class='sorting_1'></th>");
# 						}
#
# 						$tr.find("td").each(function() {
#
# 							var $td = jQuery(this);
#
# 							$td.attr("data-tit",status_column_arr[$td.index()]);
#
# 							var rowspan = parseInt($td.data("datatable-multi-row-rowspan"), 10);
# 							if (rowspan) {
# 							  $td.attr('rowspan', rowspan);
# 							}
# 						});
# 					}
#
# 				});
#
# 			}
# 			if(pre =="1"){
# 				if(!status_pre_is_first){
# 					location.href="#status_page_top";
# 				}
# 			}else{
# 				if(!status_is_first){
# 					location.href="#status_page_top";
# 				}
# 			}
# 			status_is_first = false;
# 		}
# 	});
#
# 	function status_search_function(){
#
# 		var status_search_query = jQuery("#status_searchQuery").val();
# 		var status_page_length = jQuery("#status_pageLength").val();
#
# 		status_datatable.search( status_search_query ).draw();
#
# 		if(jQuery("#status_searchArea").val() == "기타"){
# 			//console.log(status_etc_query);
# 			status_datatable.columns( 3 )
# 				.search( status_etc_query, true, false ).draw();
# 		}else{
# 			status_datatable.columns( 3 )
# 				.search( jQuery("#status_searchArea").val() ).draw();
# 		}
#
# 		status_datatable.page.len( status_page_length ).draw();
# 	}
#
# 	function go_to_page(){
# 		var page =  jQuery("#go_number").val();
# 		status_datatable.page(page -1).draw('page');
# 	}
#
# 	jQuery("#status_searchButton").on("click", function(){
# 		status_search_function();
# 	});
#
# 	jQuery("#status_init_searchButton").on("click", function(){
# 		jQuery("#status_searchQuery").val('');
# 		jQuery("#status_searchArea").val('');
# 		jQuery("#status_pageLength").val(100);
#
# 		status_search_function();
# 	});
#
# </script>
# </div>
# </div>
# <div class="new-cont" id="new-cont2">
# <link href="//www.seoul.go.kr/res_newseoul/css/jquery.dataTables.css?ver=20201218" rel="stylesheet" type="text/css"/>
# <script src="//www.seoul.go.kr/res_newseoul/js/jquery.dataTables.js"></script>
# <script>
#
# jQuery(document).ready(function() {
#
# 	jQuery('.btn-paging').on('click', function(){
# 		var ids = jQuery(this).attr('data-tit');
# 		jQuery(this).closest('.cont-page-wrap').find('.btn-paging').removeClass('on');
# 		jQuery(this).addClass('on');
# 		jQuery(this).closest('.cont-page-wrap').find('.cont-page').css('display', 'none');
# 		jQuery('#'+ids).css('display', 'block');
# 		jQuery('html, body').animate({scrollTop:jQuery('#'+ids).offset().top}, 'fast');
# 	});
#
# });
#
# </script>
# <div class="cont-page-wrap" id="status_pre_box">
# <a name="status_pre_page_top"></a>
# <div class="search-box">
# <label for="status_pre_searchArea">자치구 검색 :</label>
# <select id="status_pre_searchArea">
# <option value="">자치구 전체</option>
# <option value="강남구">강남구</option>
# <option value="강동구">강동구</option>
# <option value="강북구">강북구</option>
# <option value="강서구">강서구</option>
# <option value="관악구">관악구</option>
# <option value="광진구">광진구</option>
# <option value="구로구">구로구</option>
# <option value="금천구">금천구</option>
# <option value="노원구">노원구</option>
# <option value="도봉구">도봉구</option>
# <option value="동대문구">동대문구</option>
# <option value="동작구">동작구</option>
# <option value="마포구">마포구</option>
# <option value="서대문구">서대문구</option>
# <option value="서초구">서초구</option>
# <option value="성동구">성동구</option>
# <option value="성북구">성북구</option>
# <option value="송파구">송파구</option>
# <option value="양천구">양천구</option>
# <option value="영등포구">영등포구</option>
# <option value="용산구">용산구</option>
# <option value="은평구">은평구</option>
# <option value="종로구">종로구</option>
# <option value="중구">중구</option>
# <option value="중랑구">중랑구</option>
# <option value="기타">기타</option>
# </select>
# <select id="status_pre_pageLength" title="목록갯수 선택">
# <option value="10">10</option>
# <option value="25">25</option>
# <option value="50">50</option>
# <option selected="selected" value="100">100</option>
# </select>
# <input id="status_pre_searchQuery" name="query" type="text" value=""/>
# <button class="btn-route-search" id="status_pre_searchButton" style="display: inline-block;padding: 0 20px;height:2rem;line-height: 2rem;background: #ebebeb;border: 1px solid #ddd;" type="button">검색</button>
# <button class="btn-route-search" id="status_pre_init_searchButton" style="display: none;padding: 0 20px;height:2rem;line-height: 2rem;background: #ebebeb;border: 1px solid #ddd;" type="button">초기화</button>
# </div>
# <table class="tstyle05 tstyleP status_pre_datatable datatable-multi-row">
# <caption>서울 확진자 현황 - 연번, 환자, 확진일 등의 정보</caption>
# <colgroup>
# <col style="width: 10%;"/>
# <col style="width: 10%;"/>
# <col style="width: 10%;"/>
# <col style="width: 10%;"/>
# <col style="width: 20%;"/>
# <col style="width: 30%;"/>
# <col style="width: 10%;"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">연번</th>
# <th scope="col">환자</th>
# <th scope="col">확진일</th>
# <th scope="col">거주지</th>
# <th scope="col">여행력</th>
# <th scope="col">접촉력</th>
# <th scope="col">퇴원현황</th>
# </tr>
# </thead>
# </table>
# </div>
# <script>
#
# 	var status_etc_query = " 관악구 | 노원구 | 도봉구 | 성동구|강동구 |관악구 |광진구 |금천구 |기타|도봉구 |타시도";
# 	var status_ajax_url = "https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php";
# 	var pre = true;
# 	var status_settime = null;
# 	var status_is_first = true;
# 	var status_pre_is_first = true;
#
# 	var status_column_arr = ["","환자 번호","확진일","거주지","여행력","접촉력","퇴원현황"];
#
# 	var status_pre_datatable = jQuery('.status_pre_datatable').DataTable({
# 		columnDefs: [
# 			{type: 'natural', targets: 0}
# 		],
# 		"order" : [[0, "desc" ]],
# 		"pageLength" : 100,
# 		"search": {regex: true},
# 		"processing": true,
#         "serverSide": true,
#         "ajax": status_ajax_url,
# 		"fnDrawCallback": function() {
#
# 			//한번만 실행
# 			if(status_is_first){
# 				jQuery('.dataTables_processing').html('<img src="https://www.seoul.go.kr/res_newseoul/images/corona/ajax-loader.gif" alt="loading">');
# 			}
#
# 			var api = this.api();
# 			var page_info = api.page.info();
# 			var page_number = page_info.page +1;
#
# 			jQuery('#status_pre_box').find(".paging_simple_numbers").append("<span class='page_move'><input id='go_number_pre' type='text' class='page_number' value='"+page_number+"' /><input type='button' class='btn_page_number'  onclick='go_to_page_pre();' value='이동'/></span>");
#
# 			var rowCount = api.rows({search:'applied'}).count();
#
# 		    $table = jQuery(this);
#
# 		    $table.css("width","100%");
#
# 			if ($table.closest(".datatable-multi-row").length) {
#
# 				$table.find("tbody>tr").each(function(index) {
# 					var $tr = jQuery(this);
#
# 					//$tr.find("p.corona19_no").html(rowCount - (api.page.info().page * api.page.len()) - index);
#
# 					var extra_row = $tr.find(".extra-row-content").html();
#
# 					if (!$tr.next().hasClass('dt-added')) {
# 						$tr.after(extra_row);
#
# 						if($tr.find("td").eq(0)){
# 							var first = $tr.find("td").first();
# 							$(first).contents().unwrap().wrap("<th scope='row' class='sorting_1'></th>");
# 						}
#
# 						$tr.find("td").each(function() {
#
# 							var $td = jQuery(this);
#
# 							$td.attr("data-tit",status_column_arr[$td.index()]);
#
# 							var rowspan = parseInt($td.data("datatable-multi-row-rowspan"), 10);
# 							if (rowspan) {
# 							  $td.attr('rowspan', rowspan);
# 							}
# 						});
# 					}
#
# 				});
#
# 			}
# 			if(pre =="1"){
# 				if(!status_pre_is_first){
# 					location.href="#status_page_top";
# 				}
# 			}else{
# 				if(!status_is_first){
# 					location.href="#status_page_top";
# 				}
# 			}
# 			status_is_first = false;
# 		}
# 	});
#
# 	function status_pre_search_function(){
#
# 		var status_search_query = jQuery("#status_pre_searchQuery").val();
# 		var status_page_length = jQuery("#status_pre_pageLength").val();
#
# 		status_pre_datatable.search( status_search_query ).draw();
#
# 		if(jQuery("#status_pre_searchArea").val() == "기타"){
# 			//console.log(status_etc_query);
# 			status_pre_datatable.columns( 3 )
# 				.search( status_etc_query, true, false ).draw();
# 		}else{
# 			status_pre_datatable.columns( 3 )
# 				.search( jQuery("#status_pre_searchArea").val() ).draw();
# 		}
#
# 		status_pre_datatable.page.len( status_page_length ).draw();
# 	}
#
# 	function go_to_page_pre(){
# 		var page =  jQuery("#go_number_pre").val();
# 		status_pre_datatable.page(page -1).draw('page');
# 	}
#
# 	jQuery("#status_pre_searchButton").on("click", function(){
# 		status_pre_search_function();
# 	});
#
# 	jQuery("#status_pre_init_searchButton").on("click", function(){
# 		jQuery("#status_pre_searchQuery").val('');
# 		jQuery("#status_pre_searchArea").val('');
# 		jQuery("#status_pre_pageLength").val(100);
#
# 		status_pre_search_function();
# 	});
#
# </script>
# </div>
# </div>
# </div>
# <!--// 확진자 현황 : END -->
# </div>
# <!--// .move-cont -->
# <div class="move-cont" id="move-cont2">
# <h3 class="display-none" style="margin-top: 30px;"><span>서울 확진자 이동경로</span></h3>
# <p style="text-align: left;"> </p>
# <h5 class="update-date"><strong>('21.02.04.00시 기준)</strong></h5>
# <div class="cont-type1" style="background: #f8f8f8;margin-bottom: 30px;padding-bottom: 0;">
# <h4 style="text-align: center;font-size: 18px;"><strong style="color: #042e8b;">확진환자의 이동경로 등 정보공개 안내</strong></h4>
# <ul class="list-type-dot">
# <li>「확진환자의 이동경로 등 정보공개 지침(1판)」에 따라 확진환자의 성별, 연령, 국적, 거주지(읍면동 단위 이하) 등 <strong>개인을 특정하는 정보는 공개되지 않습니다.</strong>
# <!-- <p style="margin-top: 5px;padding-left: 15px;text-indent: -15px">- 성별, 연령, 국적, 거주지 및 직장명 등 <strong>개인을 특정하는 정보를 공개하지 않음</strong></p> -->
# <p style="margin-top: 5px;padding-left: 15px;text-indent: -15px">- 시간에 따른 개인별 동선을 공개하지 않고, <strong>장소목록 형태로 지역(시도, 시군구), 장소·유형, 상호명, 주소, 노출일시, 소독여부 정보를 공개</strong>함</p>
# <p class="btn-group" style="margin-bottom: 10px;text-align: center;"><a class="btn" href="/seoulcom/fileDownload.do?fileName=corona/open_guideline_v1.hwp" onclick="action_logging({_se_m1:'코로나19 대응 주요소식_201027_168호'});" style="margin-top: 10px;width: 100%;max-width: 370px;background: #042e8b;color: #fff;padding: 9px 20px;text-align: center;font-weight: 600;margin: 0;" target="_blank">확진환자의 이동경로 등 <span class="mobile-block">정보공개 지침 자세히보기 &gt;</span></a></p>
# </li>
# </ul>
# </div>
# <div id="rsstableId">
# <link href="//www.seoul.go.kr/res_newseoul/css/jquery.dataTables.css?ver=20201218" rel="stylesheet" type="text/css"/>
# <script src="//www.seoul.go.kr/res_newseoul/js/jquery.dataTables.js"></script>
# <script>
#
# jQuery(document).ready(function() {
#
# 	/*
# 	if(jQuery('#patients').length) {
#
# 		jQuery('.tdl').css('display', 'none');
# 		jQuery(".patient td").css({'cursor':'pointer', 'height':'54px'});
# 		jQuery('tr').removeClass('odd');
# 		jQuery('tr').filter(function(index){if(index%4==2 || index%4==1)return index}).addClass('odd');
# 		var $trList = jQuery("#patients tbody tr");
# 		jQuery('.patient').addClass('open');
# 		jQuery('.patient').next('tr').addClass('show');
# 		jQuery('.patient').next('tr').find('td').css('display','table-cell');
#
# 		if($trList.hasClass('open')) {
# 			jQuery('.open').next('tr').find('td').css('display', 'table-cell');
# 			jQuery('.open').next('tr').addClass('show');
#
# 		}
# 		jQuery('#closeAll').on('click', function(e){
# 			e.preventDefault();
# 				jQuery('.patient').removeClass('open');
# 				jQuery('.patient').next('tr').removeClass('show');
# 				jQuery('.patient').next('tr').find('td').css('display','none');
# 		});
# 		jQuery('#openAll').on('click', function(e){
# 			e.preventDefault();
# 				jQuery('.patient').addClass('open');
# 				jQuery('.patient').next('tr').addClass('show');
# 				jQuery('.patient').next('tr').find('td').css('display','table-cell');
# 		});
#
# 		jQuery('.patient td').each(function(){
# 			jQuery(this).on('click', function(){
# 				if(jQuery(this).parent().hasClass('open')){
# 					jQuery(this).parent().removeClass('open');
# 					jQuery(this).parent().next('tr').removeClass('show');
# 					jQuery(this).parent().next('tr').find('td').css('display','none');
# 				}else{
# 					jQuery(this).parent().addClass('open');
# 					jQuery(this).parent().next('tr').addClass('show');
# 					jQuery(this).parent().next('tr').find('td').css('display','table-cell');
# 				}
# 			});
# 		});
#
# 	}
# 	*/
#
# 	jQuery('.btn-paging').on('click', function(){
# 		var ids = jQuery(this).attr('data-tit');
# 		jQuery(this).closest('.cont-page-wrap').find('.btn-paging').removeClass('on');
# 		jQuery(this).addClass('on');
# 		jQuery(this).closest('.cont-page-wrap').find('.cont-page').css('display', 'none');
# 		jQuery('#'+ids).css('display', 'block');
# 		jQuery('html, body').animate({scrollTop:jQuery('#'+ids).offset().top}, 'slow');
# 	});
#
#
# });
#
# </script>
# <div class="status-confirm">
# <!-- <div class="btn-group">
# 		<button id="openAll" style="border: 1px solid #ccc;">전체 이동경로 펼치기</button>
# 		<button id="closeAll" style="border: 1px solid #ccc;">전체 이동경로 닫기</button>
# 	</div> -->
# <div id="patients" style="text-align: left;">
# <!-- <strong>※ 서울 확진자 총 명</strong> -->
# <a name="route_page_top"></a>
# <div class="cont-page-wrap">
# <div>
# <form action="" id="" method="GET" name="" onsubmit="return searchForm(this);">
# <div class="search-box search-box-new">
# <label for="search-district">자치구 검색 :</label>
# <select class="select1" id="search-district">
# <option value="">시군구 전체</option>
# <option value="">강남구</option>
# <option value="">강동구</option>
# <option value="">강북구</option>
# <option value="">강서구</option>
# <option value="">관악구</option>
# <option value="">광진구</option>
# <option value="">구로구</option>
# <option value="">금천구</option>
# <option value="">기타</option>
# <option value="">노원구</option>
# <option value="">도봉구</option>
# <option value="">동대문구</option>
# <option value="">동작구</option>
# <option value="">마포구</option>
# <option value="">서대문구</option>
# <option value="">서초구</option>
# <option value="">성동구</option>
# <option value="">성북구</option>
# <option value="">송파구</option>
# <option value="">양천구</option>
# <option value="">영등포구</option>
# <option value="">용산구</option>
# <option value="">은평구</option>
# <option value="">종로구</option>
# <option value="">중구</option>
# <option value="">중랑구</option>
# <option value="">타시도</option>
# <option value="기타">기타</option>
# </select>
# <label for="search-disinfection">소독여부 :</label>
# <select class="select2" id="search-disinfection">
# <option value="">소독여부 전체</option>
# <option value="소독완료">소독완료</option>
# </select>
# <label for="search-other">필드검색</label>
# <select class="select3" id="search-other">
# <option value="">전체</option>
# <option value="gubun">장소·유형</option>
# <option value="address">상호명</option>
# <option value="address_detail">주소</option>
# <option value="period">노출일시</option>
# </select>
# <input class="input1" id="route-searchQuery" name="query" placeholder="검색어 입력" style="display: block;" title="검색어 입력" type="text" value=""/>
# <button class="btn-route-search" id="route-searchButton" type="submit">검색</button>
# <!-- <button id="route-init-searchButton" type="button" class="btn-route-search2" style="display: inline-block;padding: 0 20px;height:2rem;line-height: 2rem;background: #ebebeb;border: 1px solid #ddd;">초기화</button> -->
# </div>
# </form>
# </div>
# <table class="route-datatable datatable-multi-row tNewStyle2">
# <caption>서울 확진자 이동경로 - 연번, 환자번호, 감염경로 등의 정보</caption>
# <colgroup>
# <col style="width: 100%;"/>
# </colgroup>
# <thead style="display: none;">
# <tr>
# <th scope="col">동</th>
# </tr>
# </thead>
# </table>
# </div>
# </div>
# </div>
# <script>
#
# 	var route_etc_query = "기타|타시도";
# 	var route_settime = null;
# 	var route_is_first = true;
#
# 	var route_table = jQuery('.route-datatable').DataTable({
# 		columnDefs: [
# 			{type: 'natural', targets: 0}
# 		],
# 		"order" : [[0, "desc" ]],
# 		"pageLength" : 100,
# 		"search": {regex: true},
# ...
# 						 label: 'Dataset 1',
# 							backgroundColor: color('#d74d02').alpha(1).rgbString(),
# 							borderColor: window.chartColors.red,
# 							borderWidth: 0,
# 							data: []
# 					}
#
# 				//var chart_text="";
#
# 				for(var i=0; i < dt.rVal.length;i++){
# 					barChartData.labels.push(dt.rVal[i].C_DATE); //새로운 날짜 세팅
# 					newDataset.data.push(dt.rVal[i].GAP); //새로운 확진자 수 세팅
# 				//	chart_text += dt.rVal[i].C_DATE+" : "+dt.rVal[i].GAP+"명, ";
# 				}
#
# 				//$("#chart_text").text(chart_text);
#
# 				barChartData.datasets.push(newDataset); //확진자 수 세팅
# 				myBar.update(); //차트 업데이트
# 			},
# 			error : function() {
# 				alert("네트워크가 불안정하거나 서버정보를 알 수 없습니다.\n 다시 시도해 주시기 바랍니다.");
# 			}
# 		});
#
# 	});
#
# 	$('#btn_find_day_jcg').click(function(e) { //일별 확진자 추이 검색 ajax
# 		if($('#jcgDay').val() == "" && $('#jcgDay').val() == ""){
# 			alert("검색할 날짜를 입력해주세요");
# 			$('#jcgDay').focus();
# 			return;
# 		}
# 		var jcgDay= $('#jcgDay').val();
#
# 		com.ajax( {
# 			type : 'POST'
# 			, url : '/coronaV/searchCoronaDayJcgStatus.do'
# 			, data : {
# 				  "jcgDay" : jcgDay
# 			}
# 			, success : function(dt) {
#
# 				//pc 그래프 세팅
# 				var dataset = barChartData3.datasets[0].data;
# 				barChartData3.datasets.splice(0,1); // 기존 확진자 수 제거
#
#
# 				barChartData3.datasets.forEach(function(dataset){
# 						dataset.data.pop();
# 				});
#
# 				myBar3.update();
# 				 //기존 데이터 삭제를 업데이트
#
#
# 				 //모바일 그래프 세팅
# 				var dataset2 = barChartData4.datasets[0].data;
# 				barChartData4.datasets.splice(0,1); // 기존 확진자 수 제거
#
#
# 				barChartData4.datasets.forEach(function(dataset){
# 						dataset.data.pop();
# 				});
#
# 				myBar4.update();
# 				 //기존 데이터 삭제를 업데이트
# 				//새로운 값 세팅
# 				 var newDataset = {
# 						 label: 'Dataset 1',
# 							backgroundColor: color('#d74d02').alpha(1).rgbString(),
# 							borderColor: window.chartColors.red,
# 							borderWidth: 0,
# 							data: []
# 					}
#
# 				//var chart_text="";
# 				newDataset.data.push(dt.JONGNOADD);
# 				newDataset.data.push(dt.JUNGGUADD);
# 				newDataset.data.push(dt.YONGSANADD);
# 				newDataset.data.push(dt.SEONGDONGADD);
# 				newDataset.data.push(dt.GWANGJINADD);
# 				newDataset.data.push(dt.DDMADD);
# 				newDataset.data.push(dt.JUNGNANGADD);
# 				newDataset.data.push(dt.SEONGBUKADD);
# 				newDataset.data.push(dt.GANGBUKADD);
# 				newDataset.data.push(dt.DOBONGADD);
# 				newDataset.data.push(dt.NOWONADD);
# 				newDataset.data.push(dt.EPADD);
# 				newDataset.data.push(dt.SDMADD);
# 				newDataset.data.push(dt.MAPOADD);
# 				newDataset.data.push(dt.YANGCHEONADD);
# 				newDataset.data.push(dt.GANGSEOADD);
# 				newDataset.data.push(dt.GUROADD);
# 				newDataset.data.push(dt.GEUMCHEONADD);
# 				newDataset.data.push(dt.YDPADD);
# 				newDataset.data.push(dt.DONGJAKADD);
# 				newDataset.data.push(dt.GWANAKADD);
# 				newDataset.data.push(dt.SEOCHOADD);
# 				newDataset.data.push(dt.GANGNAMADD);
# 				newDataset.data.push(dt.SONGPAADD);
# 				newDataset.data.push(dt.GANGDONGADD);//새로운 확진자 수 세팅
#
# 				//$("#chart_text").text(chart_text);
# 				 //피시차트
# 				barChartData3.datasets.push(newDataset); //확진자 수 세팅
# 				myBar3.update(); //차트 업데이트
#
# 				//모바일차트
# 				barChartData4.datasets.push(newDataset); //확진자 수 세팅
# 				myBar4.update(); //차트 업데이트
# 			},
# 			error : function() {
# 				alert("네트워크가 불안정하거나 서버정보를 알 수 없습니다.\n 다시 시도해 주시기 바랍니다.");
# 			}
# 		});
#
# 	});
#
#
# 	$('#btn_find_jcg_acr').click(function(e) { //자치구별 누적 확진자 추이 검색 ajax
#
# 		/* if($('#jcgsdt').val() != "" && $('#jcgedt').val() == ""){
# 			alert("마지막날짜를 입력해주세요");
# 			$('#jcgedt').focus();
# 			return;
# 		}
# 		if($('#jcgsdt').val() == "" && $('#jcgedt').val() != ""){
# 			alert("시작날짜를 입력해주세요");
# 			$('#jcgsdt').focus();
# 			return;
# 		}
#
# 		if($('#jcgsdt').val() > $('#jcgedt').val()){
# 			alert("시작날짜가 종료날짜보다 큽니다.");
# 			return;
# 		}
#
# 		var sdt= $('#jcgsdt').val();
# 		var edt= $('#jcgedt').val(); */
# 		var jcg =  $("#jachigu option:selected").val();
# 		com.ajax( {
# 			type : 'POST'
# 			, url : '/coronaV/searchJcgAccrueStatus.do'
# 			, data : {
# 				//  "sdate" : sdt,
# 				//  "edate" : edt,
# 				  "jachigu" : jcg
# 			}
# 			, success : function(dt) {
# 				var dataset = config2.data.datasets[0];
# 				var labelset = config2.data.labels;
# 				var len = labelset.length;
# 				config2.data.datasets.splice(0,1); // 기존 확진자 수 제거
# 				//기존 날짜 제거
# 				   for(var i=0; i < len ;i++){
# 					 labelset.splice(-1,1);
# 				}
#
# 				config2.data.datasets.forEach(function(dataset){
# 						dataset.data.pop();
# 				});
#
# 				 myChart5.update();
# 				 //기존 데이터 삭제를 업데이트
# 				 var rJcg = dt.jcg;
# 				 var jcgVal ;
# 				 var jcgTotal ;
# 				 if(rJcg=="jongno"){
# 					 jcgVal="종로구";
# 					 jcgTotal="519";
# 				 }else if(rJcg=="junggu"){
# 					 jcgVal="중구";
# 					 jcgTotal="381";
# 				 }else if(rJcg=="yongsan"){
# 					 jcgVal="용산구";
# 					 jcgTotal="543";
# 				 }else if(rJcg=="seongdong"){
# 					 jcgVal="성동구";
# 					 jcgTotal="601";
# 				 }else if(rJcg=="gwangjin"){
# 					 jcgVal="광진구";
# 					 jcgTotal="601";
# 				 }else if(rJcg=="ddm"){
# 					 jcgVal="동대문구";
# 					 jcgTotal="915";
# 				 }else if(rJcg=="jungnang"){
# 					 jcgVal="중랑구";
# 					 jcgTotal="1036";
# 				 }else if(rJcg=="seongbuk"){
# 					 jcgVal="성북구";
# 					 jcgTotal="1045";
# 				 }else if(rJcg=="gangbuk"){
# 					 jcgVal="강북구";
# 					 jcgTotal="649";
# 				 }else if(rJcg=="dobong"){
# 					 jcgVal="도봉구";
# 					 jcgTotal="757";
# 				 }else if(rJcg=="nowon"){
# 					 jcgVal="노원구";
# 					 jcgTotal="1050";
# 				 }else if(rJcg=="ep"){
# 					 jcgVal="은평구";
# 					 jcgTotal="986";
# 				 }else if(rJcg=="sdm"){
# 					 jcgVal="서대문구";
# 					 jcgTotal="672";
# 				 }else if(rJcg=="mapo"){
# 					 jcgVal="마포구";
# 					 jcgTotal="864";
# 				 }else if(rJcg=="yangcheon"){
# 					 jcgVal="양천구";
# 					 jcgTotal="909";
# 				 }else if(rJcg=="gangseo"){
# 					 jcgVal="강서구";
# 					 jcgTotal="1569";
# 				 }else if(rJcg=="guro"){
# 					 jcgVal="구로구";
# 					 jcgTotal="799";
# 				 }else if(rJcg=="geumcheon"){
# 					 jcgVal="금천구";
# 					 jcgTotal="402";
# 				 }else if(rJcg=="ydp"){
# 					 jcgVal="영등포구";
# 					 jcgTotal="900";
# 				 }else if(rJcg=="dongjak"){
# 					 jcgVal="동작구";
# 					 jcgTotal="1025";
# 				 }else if(rJcg=="gwanak"){
# 					 jcgVal="관악구";
# 					 jcgTotal="1207";
# 				 }else if(rJcg=="seocho"){
# 					 jcgVal="서초구";
# 					 jcgTotal="981";
# 				 }else if(rJcg=="gangnam"){
# 					 jcgVal="강남구";
# 					 jcgTotal="1179";
# 				 }else if(rJcg=="songpa"){
# 					 jcgVal="송파구";
# 					 jcgTotal="1389";
# 				 }else if(rJcg=="gangdong"){
# 					 jcgVal="강동구";
# 					 jcgTotal="766";
# 				 }
# 				 $("#jcgNm").text("[ "+jcgVal+" ] 누적 확진자 추이");
# 				 $("#jcgTotalCnt").text(jcgTotal);
# 				//새로운 값 세팅
# 				 var newDataset = {
# 						 label: '',
# 							steppedLine: false,
# 							data: [],
# 							borderColor: '#d74d02',
# 							borderWidth : 2,
# 							fill: false, // 차트 칠하기
# 							pointRadius: 3,
# 							pointBorderWidth: 3,
# 							pointBackgroundColor: '#d74d02',
# 							pointHoverRadius: 3,
# 							pointHoverBackgroundColor: '#d74d02',
# 							pointHoverBorderWidth: 0
# 					}
#
# 				var chart_text="";
#
# 				for(var i=0; i < dt.rVal.length;i++){
# 					config2.data.labels.push(dt.rVal[i].RDATE); //새로운 날짜 세팅
# 					newDataset.data.push(dt.rVal[i].JCGCNT); //새로운 확진자 수 세팅
# 					chart_text += dt.rVal[i].RDATE+" : "+dt.rVal[i].JCGCNT+"명, ";
# 				}
#
# 				$("#chart_text5").text(chart_text);
#
# 				config2.data.datasets.push(newDataset); //확진자 수 세팅
# 				myChart5.update(); //차트 업데이트
# 			},
# 			error : function() {
# 				alert("네트워크가 불안정하거나 서버정보를 알 수 없습니다.\n 다시 시도해 주시기 바랍니다.");
# 			}
# 		});
#
# 	});
#
# });
# </script>
# <button class="btn-top" type="button">상단으로</button>
# <footer id="footer">
# <p>© Seoul Metropolitan Government all rights reserved.</p>
# </footer>
# </div>
# <script src="/res_newseoul/js/jquery.waypoints.min.js"></script>
# <script src="/res_newseoul/js/jquery.counterup.js"></script>
# <script>
#
#
# function fnEventListener() {
#
# 	// 본문 바로가기
# 	$('#skip a').on('click', function(e){
# 		var links = $(this).attr('href');
# 		e.preventDefault();
# 		$(links).attr('tabindex', '0').focus().on('keydown', function(e){
# 			if (e.keyCode === 9) $(this).removeAttr('tabindex');
# 		});
#
# 	});
#
# 	// title
# 	document.title = $('.sub-menu li.on').find('a').text() + ' | 서울특별시';
#
# 	// menu click
# 	 var isMobile = {
#         Android: function () {
#                  return navigator.userAgent.match(/Android/i) == null ? false : true;
#         },
#         BlackBerry: function () {
#                  return navigator.userAgent.match(/BlackBerry/i) == null ? false : true;
#         },
#         IOS: function () {
#                  return navigator.userAgent.match(/iPhone|iPad|iPod/i) == null ? false : true;
#         },
#         Opera: function () {
#                  return navigator.userAgent.match(/Opera Mini/i) == null ? false : true;
#         },
#         Windows: function () {
#                  return navigator.userAgent.match(/IEMobile/i) == null ? false : true;
#         },
#         any: function () {
#                  return (isMobile.Android() || isMobile.BlackBerry() || isMobile.IOS() || isMobile.Opera() || isMobile.Windows());
#         }
#     };
#     var windowSize = document.body.clientWidth;
#
# 	 // 모바일 접속일 경우 ios / android 운영체제 구분
#     if(isMobile.any() && windowSize <= 1023){
#         if(isMobile.Android()){
#             $("body").addClass("android mo");
#         }else if(isMobile.IOS()){
#             $("body").addClass("ios mo");
#         }else if(isMobile.BlackBerry()){
#             $("body").addClass("android mo");
#         }else if(isMobile.Opera()){
#             $("body").addClass("android mo");
#         }else if(isMobile.Windows()){
#             $("body").addClass("android mo");
#         }
#     }
# 	if(!isMobile.any()) {
# 		$("body").addClass("desktop");
# 	};
# 	if(windowSize <= 1023){
# 		 $("body").addClass("small");
# 	}
#
# 	$('.sub #menu>li>a').on('click', function(e){
#
# 		if($('body').hasClass('mo') || $('body').hasClass('small')) {
# 			e.preventDefault();
# 			if($(this).closest('li').hasClass('active')) {
# 				// do nothing
# 			} else {
# 				$('.sub #menu>li').removeClass('selected active');
# 				$(this).closest('li').addClass('selected active');
# 			}
# 		}
#
#
# 	});
#
#
# 	$('.qna_list .qlist a').on('click', function(e){
# 		e.preventDefault();
# 		var ids = $(this).attr('href');
# 		var conts = $(this).closest('.qna_list').find('.alist');
#
# 		if($(this).hasClass('opened')) {
# 			$('.qna_list .qlist a').removeClass('opened');
# 			$(this).removeClass('opened');
# 			$('.alist').css('display', 'none');
# 		} else {
# 			$('.qna_list .qlist a').removeClass('opened');
# 			$(this).addClass('opened');
# 			$('.alist').css('display', 'none');
# 			$(ids).css('display', 'block');
# 			//$('.alist').slideUp();
# 			//$(ids).slideDown();
# 		}
#
# 	});
#
# 	$('.btn-menu-open').on('click', function(){
# 		if($(this).hasClass('open')) {
# 			$('.sub-menu').slideDown();
# 			$('.bg-visual').slideDown();
# 			$(this).removeClass('open').find('span').text('메뉴 접기');
# 			$('.menu-wrap').removeClass('open');
# 		} else {
# 			$('.sub-menu').slideUp();
# 			$('.bg-visual').slideUp();
# 			$(this).addClass('open').find('span').text('메뉴 펼치기');
# 			$('.menu-wrap').addClass('open');
# 		}
# 	});
# 	$('.move-tab li button').on('click', function(e){
# 		//e.preventDefault();
# 		$(this).closest('.move-tab').find('li button').removeClass('on');
# 		$(this).addClass('on');
# 		var ids = $(this).attr('data-url');
# 		$(this).closest('.layout-sub').find('.move-cont').css('display', 'none');
# 		$(ids).css('display', 'block');
# 		/* if($(this).hasClass('btn-tab3')) {
# 			$('.chart-wrap').removeClass('display-block');
# 			$('.map-status').addClass('display-block');
# 			$('#bannerzone').addClass('display-block');
# 		} else if($(this).hasClass('btn-tab2')) {
# 			$('#bannerzone').removeClass('display-block');
# 		} else {
# 			$('.chart-wrap').addClass('display-block');
# 			$('.map-status').removeClass('display-block');
# 			$('#bannerzone').addClass('display-block');
# 		} */
# 	});
#
# 	$('.new-tab li button').on('click', function(e){
# 		//e.preventDefault();
# 		$(this).closest('.new-tab').find('li button').removeClass('on');
# 		$(this).addClass('on');
# 		var ids = $(this).attr('data-url');
# 		$(this).closest('.tab-cont-wrap').find('.new-cont').css('display', 'none');
# 		$(ids).css('display', 'block');
# 	});
#
# 	// 진료소 버튼 클릭시 팝업으로 열리게
# 	$('.inner5 [class*="jsTimerpopup-"]').on('click', function() {
# 		window.open($(this).attr('href'), '', 'resizable=no,status=no,location=no,toolbar=no,menubar=no,fullscreen=no,scrollbars=yes,dependent=no,width=800,height=800,top=0,left=0');
# 		return false;
# 	});
#
# 	// 페이징
# 	$('.btn-paging').on('click', function(){
# 		var ids = $(this).attr('data-tit');
# 		$(this).closest('.cont-page-wrap').find('.btn-paging').removeClass('on');
# 		$(this).addClass('on');
# 		$(this).closest('.cont-page-wrap').find('.cont-page').css('display', 'none');
# 		$('#'+ids).css('display', 'block');
# 		$('html, body').animate({scrollTop:$('#'+ids).offset().top}, 'fast');
# 	});
#
# 	if(jQuery('.tstyle05 .status2').length) {
# 		jQuery('.tstyle05 .status2').closest('tr').addClass('statustr');
# 	}
#
# 	if(jQuery('.patient .status2').length) {
# 		jQuery('.patient .status2').closest('tr').addClass('statustr').next('tr').addClass('statustr');
# 	}
#
# 	// tab focus
# 	var params = com.util.parsUrl(window.location.search).param.tab;
# 	switch (params){
# 		case '1' : //발생동향
# 			console.log('1');
# 			location.href = '/coronaV/coronaStatus.do?menu_code=01';
# 			break;
# 		case '2' : //예방행동수칙 -> 잠시멈춤 캠페인
# 			location.href = '/coronaV/coronaStatus.do?menu_code=14';
# 			break;
# 		case '3' : //홍보물 -> 예방행동수칙 & 홍보물
# 			location.href = '/coronaV/coronaStatus.do?menu_code=05';
# 			break;
# 		case '4' : //선별진료소
# 			location.href = '/coronaV/coronaStatus.do?menu_code=03';
# 			break;
# 		case '5' : //관련qna
# 			location.href = '/coronaV/coronaStatus.do';
# 			break;
# 		case '6' : //보도자료
# 			location.href = '/coronaV/coronaStatus.do?menu_code=06';
# 			break;
# 		case '7' : //일일브리핑
# 			location.href = '/coronaV/coronaStatus.do?menu_code=07';
# 			break;
# 	}
# }
#
#
# function createComp() {
# 	fnEventListener();
# };
#
# $(window).on('resize', function() {
#   if($(window).width() <= 1023) {
#     $('body').addClass('small');
#   }else {
#     $('body').removeClass('small');
#   }
# });
#
# $(document).ready(function() {
#
# 	// 초기실행 (필수)
# 	createComp();
# 	// 발생동향- 이동경로
#
# 	$('.tdl').css('display', 'none');
# 	$(".patient td").css({'cursor':'pointer', 'height':'54px'});
# 	$('tr').removeClass('odd');
# 	$('tr').filter(function(index){if(index%4==2 || index%4==1)return index}).addClass('odd');
# 	var $trList = $("#patients tbody tr");
# 		//$trList.eq('1').addClass('open');
# 	$('.patient').addClass('open');
# 	$('.patient').next('tr').addClass('show');
# 	$('.patient').next('tr').find('td').css('display','table-cell');
#
# 	if($trList.hasClass('open')) {
# 		$('.open').next('tr').find('td').css('display', 'table-cell');
# 		$('.open').next('tr').addClass('show');
#
# 	}
# 	$('#closeAll').on('click', function(e){
# 		e.preventDefault();
# 			$('.patient').removeClass('open');
# 			$('.patient').next('tr').removeClass('show');
# 			$('.patient').next('tr').find('td').css('display','none');
# 	});
# 	$('#openAll').on('click', function(e){
# 		e.preventDefault();
# 			$('.patient').addClass('open');
# 			$('.patient').next('tr').addClass('show');
# 			$('.patient').next('tr').find('td').css('display','table-cell');
# 	});
#
# });
#
# </script>
# <script>
# 	(function(global, $) {
# 		'use strict';
# 		var _scope, ctrl, topBtn;
# 		var init = function() {
# 			_scope = global;
# 			ctrl = false;
# 			topBtn = document.querySelector('.btn-top');
# 			bind();
# 		};
# 		var bind = function() {
# 			$(_scope).on('scroll', function() {
# 				var _scrollTop = $(_scope).scrollTop();
# 				if(ctrl == true && _scrollTop == 0) {
# 					ctrl = false;
# 					$(topBtn).removeClass('show');
# 				} else if( ctrl == false && _scrollTop > 20 ) {
# 					ctrl = true;
# 					$(topBtn).addClass('show');
# 					$(topBtn).off('click').on('click', function() {
# 						$("html, body").animate({ scrollTop: 0 }, 300);
# 					});
# 				}
# 			});
# 		};
# 		init();
# 	})(window, jQuery);
# </script>
# <script>
# var clipboard = new ClipboardJS('.icon-share-share');
#
# clipboard.on('success', function(e) {
# 	alert('링크 복사되었습니다');
# 	//console.log('복사');
# });
#
# clipboard.on('error', function(e) {
# 	console.log('오류');
# });
# </script>
# <!-- weblog -->
# <script src="//weblog.eseoul.go.kr/wlo/js/install.js"></script>
# <!-- //weblog -->
# </body>
# </html>

# %%
df
# Out:
# []

# %%
for i in range(148):
    url = f'https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw=4&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc&start={100*i}&length=100&search%5Bvalue%5D=&search%5Bregex%5D'
    response = requests.get(url).text
    data = BeautifulSoup(response, 'html.parser')
    print(f'{i}페이지 작업 성공')
# Out:
# 0페이지 작업 성공
# 1페이지 작업 성공
# 2페이지 작업 성공
# 3페이지 작업 성공
# 4페이지 작업 성공
# 5페이지 작업 성공
# 6페이지 작업 성공
# 7페이지 작업 성공
# 8페이지 작업 성공
# 9페이지 작업 성공
# 10페이지 작업 성공
# 11페이지 작업 성공
# 12페이지 작업 성공
# 13페이지 작업 성공
# 14페이지 작업 성공
# 15페이지 작업 성공
# 16페이지 작업 성공
# 17페이지 작업 성공
# 18페이지 작업 성공
# 19페이지 작업 성공
# 20페이지 작업 성공
# 21페이지 작업 성공
# 22페이지 작업 성공
# 23페이지 작업 성공
# 24페이지 작업 성공
# 25페이지 작업 성공
# 26페이지 작업 성공
# 27페이지 작업 성공
# 28페이지 작업 성공
# 29페이지 작업 성공
# 30페이지 작업 성공
# 31페이지 작업 성공
# 32페이지 작업 성공
# 33페이지 작업 성공
# 34페이지 작업 성공
# 35페이지 작업 성공
# 36페이지 작업 성공
# 37페이지 작업 성공
# 38페이지 작업 성공
# 39페이지 작업 성공
# 40페이지 작업 성공
# 41페이지 작업 성공
# 42페이지 작업 성공
# 43페이지 작업 성공
# 44페이지 작업 성공
# 45페이지 작업 성공
# 46페이지 작업 성공
# 47페이지 작업 성공
# 48페이지 작업 성공
# 49페이지 작업 성공
# 50페이지 작업 성공
# 51페이지 작업 성공
# 52페이지 작업 성공
# 53페이지 작업 성공
# 54페이지 작업 성공
# 55페이지 작업 성공
# 56페이지 작업 성공
# 57페이지 작업 성공
# 58페이지 작업 성공
# 59페이지 작업 성공
# 60페이지 작업 성공
# 61페이지 작업 성공
# 62페이지 작업 성공
# 63페이지 작업 성공
# 64페이지 작업 성공
# 65페이지 작업 성공
# 66페이지 작업 성공
# 67페이지 작업 성공
# 68페이지 작업 성공
# 69페이지 작업 성공
# 70페이지 작업 성공
# 71페이지 작업 성공
# 72페이지 작업 성공
# 73페이지 작업 성공
# 74페이지 작업 성공
# 75페이지 작업 성공
# 76페이지 작업 성공
# 77페이지 작업 성공
# 78페이지 작업 성공
# 79페이지 작업 성공
# 80페이지 작업 성공
# 81페이지 작업 성공
# 82페이지 작업 성공
# 83페이지 작업 성공
# 84페이지 작업 성공
# 85페이지 작업 성공
# 86페이지 작업 성공
# 87페이지 작업 성공
# 88페이지 작업 성공
# 89페이지 작업 성공
# 90페이지 작업 성공
# 91페이지 작업 성공
# 92페이지 작업 성공
# 93페이지 작업 성공
# 94페이지 작업 성공
# 95페이지 작업 성공
# 96페이지 작업 성공
# 97페이지 작업 성공
# 98페이지 작업 성공
# 99페이지 작업 성공
# 100페이지 작업 성공
# 101페이지 작업 성공
# 102페이지 작업 성공
# 103페이지 작업 성공
# 104페이지 작업 성공
# 105페이지 작업 성공
# 106페이지 작업 성공
# 107페이지 작업 성공
# 108페이지 작업 성공
# 109페이지 작업 성공
# 110페이지 작업 성공
# 111페이지 작업 성공
# 112페이지 작업 성공
# 113페이지 작업 성공
# 114페이지 작업 성공
# 115페이지 작업 성공
# 116페이지 작업 성공
# 117페이지 작업 성공
# 118페이지 작업 성공
# 119페이지 작업 성공
# 120페이지 작업 성공
# 121페이지 작업 성공
# 122페이지 작업 성공
# 123페이지 작업 성공
# 124페이지 작업 성공
# 125페이지 작업 성공
# 126페이지 작업 성공
# 127페이지 작업 성공
# 128페이지 작업 성공
# 129페이지 작업 성공
# 130페이지 작업 성공
# 131페이지 작업 성공
# 132페이지 작업 성공
# 133페이지 작업 성공
# 134페이지 작업 성공
# 135페이지 작업 성공
# 136페이지 작업 성공
# 137페이지 작업 성공
# 138페이지 작업 성공
# 139페이지 작업 성공
# 140페이지 작업 성공
# 141페이지 작업 성공
# 142페이지 작업 성공
# 143페이지 작업 성공
# 144페이지 작업 성공
# 145페이지 작업 성공
# 146페이지 작업 성공
# 147페이지 작업 성공

# %%
df=data.select("p.corona19_no")

# %%
df
# Out:
# [<p class="corona19_no">10055&lt;\/p&gt;","37369","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10054&lt;\/p&gt;","37359","2020-12-05","\uc911\ub791\uad6c","-","\uc911\ub791\uad6c \uc2e4\ub0b4 \uccb4\uc721\uc2dc\uc124 \u2161 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10053&lt;\/p&gt;","37337","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10052&lt;\/p&gt;","37019","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10051&lt;\/p&gt;","37013","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10050&lt;\/p&gt;","37361","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3 ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10054&lt;\/p&gt;","37359","2020-12-05","\uc911\ub791\uad6c","-","\uc911\ub791\uad6c \uc2e4\ub0b4 \uccb4\uc721\uc2dc\uc124 \u2161 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10053&lt;\/p&gt;","37337","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10052&lt;\/p&gt;","37019","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10051&lt;\/p&gt;","37013","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10050&lt;\/p&gt;","37361","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05" ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10053&lt;\/p&gt;","37337","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10052&lt;\/p&gt;","37019","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10051&lt;\/p&gt;","37013","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10050&lt;\/p&gt;","37361","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05", ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10052&lt;\/p&gt;","37019","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10051&lt;\/p&gt;","37013","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10050&lt;\/p&gt;","37361","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae3 ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10051&lt;\/p&gt;","37013","2020-12-05","\uc911\uad6c","-","\uc911\uad6c \uc18c\uc7ac \uc2dc\uc7a5(\ub0a8\ub300\ubb38\uc2dc\uc7a5) \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10050&lt;\/p&gt;","37361","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10031&lt;\/p&gt;","37112","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811 ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10050&lt;\/p&gt;","37361","2020-12-05","\uc911\ub791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10031&lt;\/p&gt;","37112","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10030&lt;\/p&gt;","37109","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10049&lt;\/p&gt;","37358","2020-12-05","\uc911\ub791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10031&lt;\/p&gt;","37112","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10030&lt;\/p&gt;","37109","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10029&lt;\/p&gt;","37105","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10048&lt;\/p&gt;","37011","2020-12-05","\uc911\uad6c","-","\uac15\ub0a8\uad6c \uc5f0\uae30\ud559\uc6d0 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10031&lt;\/p&gt;","37112","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10030&lt;\/p&gt;","37109","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10029&lt;\/p&gt;","37105","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10028&lt;\/p&gt;","37242","2020-12-05","\uc885\ub85c\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10047&lt;\/p&gt;","37223","2020-12-05","\uc11c\ub300\ubb38\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10031&lt;\/p&gt;","37112","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10030&lt;\/p&gt;","37109","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10029&lt;\/p&gt;","37105","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10028&lt;\/p&gt;","37242","2020-12-05","\uc885\ub85c\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10027&lt;\/p&gt;","37097","2020-12-05","\uc591\ucc9c\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828", ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10046&lt;\/p&gt;","37144","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10045&lt;\/p&gt;","37145","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10044&lt;\/p&gt;","37147","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc784\uc6a9\ub2e8\uae30\uace0\uc2dc \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10043&lt;\/p&gt;","37322","2020-12-05","\ub3d9\uc791\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10042&lt;\/p&gt;","37132","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10041&lt;\/p&gt;","37256","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10040&lt;\/p&gt;","37248","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status2">\uc0ac\ub9dd&lt;\/b&gt;"],["<p class="corona19_no">10039&lt;\/p&gt;","37018","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10038&lt;\/p&gt;","37237","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10037&lt;\/p&gt;","37150","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10036&lt;\/p&gt;","37129","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10035&lt;\/p&gt;","37137","2020-12-05","\ub3d9\uc791\uad6c","-","\ub3d9\uc791\uad6c \uc0ac\uc6b0\ub098 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10034&lt;\/p&gt;","37245","2020-12-05","\ub3d9\uc791\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10033&lt;\/p&gt;","37083","2020-12-05","\ub3d9\uc791\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10032&lt;\/p&gt;","37115","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10031&lt;\/p&gt;","37112","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10030&lt;\/p&gt;","37109","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10029&lt;\/p&gt;","37105","2020-12-05","\uac15\ub3d9\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10028&lt;\/p&gt;","37242","2020-12-05","\uc885\ub85c\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10027&lt;\/p&gt;","37097","2020-12-05","\uc591\ucc9c\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10026&lt;\/p&gt;","37110","2020-12-05","\ub3c4\ubd09\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b cl ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
# ...
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10012&lt;\/p&gt;","37177","2020-12-05","\uac15\ubd81\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10011&lt;\/p&gt;","37174","2020-12-05","\uac15\ubd81\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10010&lt;\/p&gt;","37235","2020-12-05","\uad11\uc9c4\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10009&lt;\/p&gt;","37230","2020-12-05","\uad11\uc9c4\uad6c","-","\uc911\uad6c \uc18c\uc7ac \ucf5c\uc13c\ud130\u2161 \uad00\ub828(\uba54\ub9ac\uce20\ud654\uc7ac)","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10008&lt;\/p&gt;","37236","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10007&lt;\/p&gt;","37225","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10011&lt;\/p&gt;","37174","2020-12-05","\uac15\ubd81\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10010&lt;\/p&gt;","37235","2020-12-05","\uad11\uc9c4\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10009&lt;\/p&gt;","37230","2020-12-05","\uad11\uc9c4\uad6c","-","\uc911\uad6c \uc18c\uc7ac \ucf5c\uc13c\ud130\u2161 \uad00\ub828(\uba54\ub9ac\uce20\ud654\uc7ac)","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10008&lt;\/p&gt;","37236","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10007&lt;\/p&gt;","37225","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10010&lt;\/p&gt;","37235","2020-12-05","\uad11\uc9c4\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10009&lt;\/p&gt;","37230","2020-12-05","\uad11\uc9c4\uad6c","-","\uc911\uad6c \uc18c\uc7ac \ucf5c\uc13c\ud130\u2161 \uad00\ub828(\uba54\ub9ac\uce20\ud654\uc7ac)","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10008&lt;\/p&gt;","37236","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10007&lt;\/p&gt;","37225","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10009&lt;\/p&gt;","37230","2020-12-05","\uad11\uc9c4\uad6c","-","\uc911\uad6c \uc18c\uc7ac \ucf5c\uc13c\ud130\u2161 \uad00\ub828(\uba54\ub9ac\uce20\ud654\uc7ac)","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10008&lt;\/p&gt;","37236","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10007&lt;\/p&gt;","37225","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10008&lt;\/p&gt;","37236","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10007&lt;\/p&gt;","37225","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10007&lt;\/p&gt;","37225","2020-12-05","\uad11\uc9c4\uad6c","-","\uc885\ub85c\uad6c \uc18c\uc7ac \ud30c\uace0\ub2e4\ud0c0\uc6b4 \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10006&lt;\/p&gt;","37009","2020-12-05","\uc131\ubd81\uad6c","-","\ub3d9\uc791\uad6c \ucd5c\ube44\uc57c \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10005&lt;\/p&gt;","37079","2020-12-05","\uc131\ubd81\uad6c","-","\ud0c0\uc2dc\ub3c4 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10004&lt;\/p&gt;","36987","2020-12-05","\uad6c\ub85c\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p></b></p>,
#  <p class="corona19_no">10003&lt;\/p&gt;","37010","2020-12-05","\ub178\uc6d0\uad6c","-","\uae30\ud0c0 \ud655\uc9c4\uc790 \uc811\ucd09","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p></b></p>,
#  <p class="corona19_no">10002&lt;\/p&gt;","37094","2020-12-05","\ub178\uc6d0\uad6c","-","\uac10\uc5fc\uacbd\ub85c \uc870\uc0ac\uc911","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"],["<p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p></b></p>,
#  <p class="corona19_no">10001&lt;\/p&gt;","37213","2020-12-05","\uae08\ucc9c\uad6c","-","\uad6c\ub85c\uad6c \uc18c\uc7ac \ubcf4\ud5d8\ud68c\uc0ac \uad00\ub828","<b class="status1">\ud1f4\uc6d0&lt;\/b&gt;"]]}
#
#  </b></p>]
