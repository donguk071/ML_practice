# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import time
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup

import html5lib

# %%
for i in range(148):
    url = f'https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw=4&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc&start={100*i}&length=100&search%5Bvalue%5D=&search%5Bregex%5D'
    response = requests.get(url).text
    data = BeautifulSoup(response, 'html.parser')
    print(f'{i}페이지 작업 성공')
# Out:
# 0페이지 작업 성공
# 1페이지 작업 성공
# 2페이지 작업 성공
# 3페이지 작업 성공
# 4페이지 작업 성공
# 5페이지 작업 성공
# 6페이지 작업 성공
# 7페이지 작업 성공
# 8페이지 작업 성공
# 9페이지 작업 성공
# 10페이지 작업 성공
# 11페이지 작업 성공
# 12페이지 작업 성공
# 13페이지 작업 성공
# 14페이지 작업 성공
# 15페이지 작업 성공
# 16페이지 작업 성공
# 17페이지 작업 성공
# 18페이지 작업 성공
# 19페이지 작업 성공
# 20페이지 작업 성공
# 21페이지 작업 성공
# 22페이지 작업 성공
# 23페이지 작업 성공
# 24페이지 작업 성공
# 25페이지 작업 성공
# 26페이지 작업 성공
# 27페이지 작업 성공
# 28페이지 작업 성공
# 29페이지 작업 성공
# 30페이지 작업 성공
# 31페이지 작업 성공
# 32페이지 작업 성공
# 33페이지 작업 성공
# 34페이지 작업 성공
# 35페이지 작업 성공
# 36페이지 작업 성공
# 37페이지 작업 성공
# 38페이지 작업 성공
# 39페이지 작업 성공
# 40페이지 작업 성공
# 41페이지 작업 성공
# 42페이지 작업 성공
# 43페이지 작업 성공
# 44페이지 작업 성공
# 45페이지 작업 성공
# 46페이지 작업 성공
# 47페이지 작업 성공
# 48페이지 작업 성공
# 49페이지 작업 성공
# 50페이지 작업 성공
# 51페이지 작업 성공
# 52페이지 작업 성공
# 53페이지 작업 성공
# 54페이지 작업 성공
# 55페이지 작업 성공
# 56페이지 작업 성공
# 57페이지 작업 성공
# 58페이지 작업 성공
# 59페이지 작업 성공
# 60페이지 작업 성공
# 61페이지 작업 성공
# 62페이지 작업 성공
# 63페이지 작업 성공
# 64페이지 작업 성공
# 65페이지 작업 성공
# 66페이지 작업 성공
# 67페이지 작업 성공
# 68페이지 작업 성공
# 69페이지 작업 성공
# 70페이지 작업 성공
# 71페이지 작업 성공
# ...

# %%
data = json.loads(response)

# %%
data
# Out:
# {'draw': 2,
#  'recordsTotal': 10000,
#  'recordsFiltered': 10000,
#  'data': [["<p class='corona19_no'>100</p>",
#    '5377',
#    '2020-03-04',
#    '동대문구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>99</p>",
#    '5592',
#    '2020-03-04',
#    '동대문구',
#    '-',
#    '동대문관련(교회pc방)',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>98</p>",
#    '4645',
#    '2020-03-02',
#    '도봉구 ',
#    '-',
#    '감염경로 조사중',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>97</p>",
#    '4517',
#    '2020-03-02',
#    '강남구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>96</p>",
#    '4743',
#    '2020-03-02',
#    '서초구 ',
#    '-',
#    '감염경로 조사중',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>95</p>",
#    '4224',
#    '2020-03-02',
#    '영등포구',
#    '-',
#    '성동구 아파트 관리사무소',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>94</p>",
# ...

# %%
df = pd.DataFrame(data['data'])
df.rename(columns={2 : 'date'},inplace = True)
df.rename(columns={1 : 'number'},inplace = True)
df.rename(columns={3 : 'place'},inplace = True)
df.rename(columns={5 : 'how'},inplace = True)

df.drop(0, axis=1, inplace=True)
df.drop(4, axis=1, inplace=True)
df.drop(6, axis=1, inplace=True)

df
# Out:
#    number        date place           how
# 0    5377  2020-03-04  동대문구    타시도 확진자 접촉
# 1    5592  2020-03-04  동대문구  동대문관련(교회pc방)
# 2    4645  2020-03-02  도봉구       감염경로 조사중
# 3    4517  2020-03-02   강남구     기타 확진자 접촉
# 4    4743  2020-03-02  서초구       감염경로 조사중
# ..    ...         ...   ...           ...
# 95      9  2020-01-31   성북구     기타 확진자 접촉
# 96      7  2020-01-30   마포구          해외유입
# 97      6  2020-01-30   종로구      종로구 집단발병
# 98      5  2020-01-30   중랑구          해외유입
# 99      2  2020-01-24   강서구          해외유입
#
# [100 rows x 4 columns]

# %%
for i in range(148):
    url=f'https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php?draw=2&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc&start={i*100}&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1612487334119'
    response = requests.get(url).text
    data = BeautifulSoup(response, 'html.parser')
    print(f'{i}페이지 작업 성공')
# Out:
# 0페이지 작업 성공
# 1페이지 작업 성공
# 2페이지 작업 성공
# 3페이지 작업 성공
# 4페이지 작업 성공
# 5페이지 작업 성공
# 6페이지 작업 성공
# 7페이지 작업 성공
# 8페이지 작업 성공
# 9페이지 작업 성공
# 10페이지 작업 성공
# 11페이지 작업 성공
# 12페이지 작업 성공
# 13페이지 작업 성공
# 14페이지 작업 성공
# 15페이지 작업 성공
# 16페이지 작업 성공
# 17페이지 작업 성공
# 18페이지 작업 성공
# 19페이지 작업 성공
# 20페이지 작업 성공
# 21페이지 작업 성공
# 22페이지 작업 성공
# 23페이지 작업 성공
# 24페이지 작업 성공
# 25페이지 작업 성공
# 26페이지 작업 성공
# 27페이지 작업 성공
# 28페이지 작업 성공
# 29페이지 작업 성공
# 30페이지 작업 성공
# 31페이지 작업 성공
# 32페이지 작업 성공
# 33페이지 작업 성공
# 34페이지 작업 성공
# 35페이지 작업 성공
# 36페이지 작업 성공
# 37페이지 작업 성공
# 38페이지 작업 성공
# 39페이지 작업 성공
# 40페이지 작업 성공
# 41페이지 작업 성공
# 42페이지 작업 성공
# 43페이지 작업 성공
# 44페이지 작업 성공
# 45페이지 작업 성공
# 46페이지 작업 성공
# 47페이지 작업 성공
# 48페이지 작업 성공
# 49페이지 작업 성공
# 50페이지 작업 성공
# 51페이지 작업 성공
# 52페이지 작업 성공
# 53페이지 작업 성공
# 54페이지 작업 성공
# 55페이지 작업 성공
# 56페이지 작업 성공
# 57페이지 작업 성공
# 58페이지 작업 성공
# 59페이지 작업 성공
# 60페이지 작업 성공
# 61페이지 작업 성공
# 62페이지 작업 성공
# 63페이지 작업 성공
# 64페이지 작업 성공
# 65페이지 작업 성공
# 66페이지 작업 성공
# 67페이지 작업 성공
# 68페이지 작업 성공
# 69페이지 작업 성공
# 70페이지 작업 성공
# 71페이지 작업 성공
# ...

# %%
data = json.loads(response)
data
# Out:
# {'draw': 2, 'recordsTotal': 10000, 'recordsFiltered': 10000, 'data': []}

# %%
df2 = pd.DataFrame(data['data'])
df2.rename(columns={2 : 'date'},inplace = True)
df2.rename(columns={1 : 'number'},inplace = True)
df2.rename(columns={3 : 'place'},inplace = True)
df2.rename(columns={5 : 'how'},inplace = True)

df2.drop(0, axis=1, inplace=True)
df2.drop(4, axis=1, inplace=True)
df2.drop(6, axis=1, inplace=True)

df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-b6f20359ecb7> in <module>
#       5 df2.rename(columns={5 : 'how'},inplace = True)
#       6
# ----> 7 df2.drop(0, axis=1, inplace=True)
#       8 df2.drop(4, axis=1, inplace=True)
#       9 df2.drop(6, axis=1, inplace=True)
#
# c:\users\drago\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# c:\users\drago\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
# ...
